# %% [markdown]
# ## Rule based approaches
#
# For trivial tasks, we do not always to use machine learning.
#
# ![image.png](attachment:image.png)

# %%
#this was before ML
    #write rules: set of keywords. When you see this keyword, goes to spam 
        #writing rules get hard, cancel eachother
#What is ML: Song likes second one better
    #finding hidden insights
    #want ML to look at emails, then create the rules on it's own

# %% [markdown]
# ## What is Machine Learning?
# - Machine learning is a method of data analysis that automates analytical model building.
# - Using algorithms that iteratively learn from data, machine learning allows computers to find hidden insights without being explicitly programmed where to look.
#
# ## What is it used for?
# - Fraud detection.
# - Web search results.
# - Real-time ads on web pages
# - Credit scoring and next-best offers.
# - Prediction of equipment failures.
# - New pricing models.
# - Network intrusion detection.
# - Recommendation Engines
# - Customer Segmentation
# - Text Sentiment Analysis
# - Predicting Customer Churn
# - Pattern and image recognition.
# - Email spam filtering.
# - Financial Modeling

# %% [markdown]
# ## General process of machine learning projects
# ![machine%20learning%20process.png](attachment:machine%20learning%20process.png)

# %%
'''
Start with data aquisition. Sometimes have to convince collaborators- if you can give me right data, 
    then project is half way done. 
    
Sometimes the issue is the price. Example: Buoy data - someone has to pay to maintain. 
Sometimes people reluctant to give data- rules to get access for privacy. 
Sometimes have to know DBA (database administer)
    Can't have direct access

Model training and building- iterative, may have multiple times until get result

Have to get very clear meaning of what the client wants:
    Client says "do machine learning for me", they don't know what they want. 
    Have to have long conversation : what problem look into? 

Model deployment
    If you want this proccess to be automated- like predicting the sales of your company. 
        (predict sales for next month example): then need to deploy model to server, keep running, etc. 
        
        
    
'''

# %% [markdown]
# ## Supervised Learning
# **Supervised learning** algorithms are trained using labeled examples, such as an input where the desired  output is known. For example, a piece of equipment could have data points labeled either “F” (failed) or “R” (runs).
#
# - The learning algorithm receives a set of inputs along with the corresponding correct outputs, and the algorithm learns by comparing its actual output with correct outputs to find errors.
# - It then modifies the model accordingly.
# - Through methods like classification, regression, prediction and gradient boosting, supervised learning uses patterns to predict the values of the label on additional unlabeled data.
# - Supervised learning is commonly used in applications where historical data predicts likely future events.
#
#
#
# ![spam%20filtering.png](attachment:spam%20filtering.png)
#
# Some other applications:
# - For example, it can anticipate when credit card  transactions are likely to be fraudulent or which insurance customer is likely to file a claim.
# - Or it can attempt to predict the price of a house based on different features for houses for which we have historical price data.

# %%
'''
Have tagged emails to be ordinary or spam email
I want to send all the tagged emails to a ML model
After ML model learns from training dataset, with the ordinary vs. spam emails (already labeled)

Eventually I want to give it a new email, and model should be able to tell me if it is spam or not

I tag emails first, send data WITH TAGS to ML model, so ML finds important features from training, so can predict label. 
This is goal of supervised learning. 
    supervised means training data is already tagged/labeled. 
    
Labels are not continuous data (continuous- predict value, like in linear regression)

Labels: know ground truths

No labels=unsupervised
'''

# %% [markdown]
# ###  classification vs. prediction
# "Data Mining Concepts and Techniques" by Han and Kamber
#
# - predicting class labels is **classification**
# - predicting values (e.g. using regression techniques) is **prediction**.

# %% [markdown]
# ## Exercise
# Provided below are 4 example applications of machine learning. Which of them is a supervised classification problem?
#
# 1. Using labeled financial data to predict whether the value of a stock will go up or go down next week.
#
# 2. Using labeled housing price data to predict the price of a new house based on various features.
#
# 3. Using unlabeled data to cluster the students of an online education company into different categories based on their learning styles.
#
# 4. Using labeled financial data to predict what the value of a stock will be next week.

# %%
'''
1. Supervised classification (up vs. down)
2. Supervised prediction (price)
3. Unsupervised classification
4. Supervised Prediction (price)
'''

# %% [markdown]
# ## Unsupervised Learning
# **Unsupervised learning** is used against data that has no historical labels. The system is not told the "right answer." The algorithm must figure out what is being shown. The goal is to explore the data and find some structure within. Or it can find the main attributes that separate customer segments from each other. Popular techniques include self-organizing maps, nearest-neighbor mapping, k-means clustering and singular value decomposition.
#
# These algorithms are also used to segment text topics, recommend items and identify data outliers.

# %%
'''
run online quizzing system, give them quizes every week

Then find clusters (clustering): 
'early birds'
'last minute'

Association rule:
features which show up together. 
Example: 
If you collected data of shopping records of grocery store. 
    Find that customers that find diapers are very likely to buy beers. 
    Fathers staying at home, taking care of baby. 
What are the features/multiple features which show up together

So manager of grocery store: but diapers on one side of store, beer on other side of store so they
    may see something to buy more stuff

'''

# %% [markdown]
# Clustering
# - K-means
# - Hierarchical clustering
#
# Association rule mining
# - Apriori

# %%
'''
Re-inforcement learning 
    Song doesn't agree this is ML (some textbooks do)
    

'''

# %% [markdown]
# ## Other categories?
#
# Some online material may say there is another type of machine learning - Reinforcement Learning. <i>Personally</i> I would not agree with this. The difference about supervised learning and unsupervised learning is whether or not they are trained with human supervision (labels/**ground truth data**).
#
# ### Semisupervised Learning
# Some algorithms can deal with partially labeled training data, usually a lot of unlabeled data and a little bit of labeled data. This is called semisupervised learning.
#
# ![semisupervised.png](attachment:semisupervised.png)

# %%
'''
Some labeled data, but majority is unlabeled. 


Active learning
    Ask domain expert on ones that are hard
    
    
        
'''

# %% [markdown]
# ![image.png](attachment:image.png)
